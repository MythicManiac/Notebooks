# %%
import os
import tensorflow as tf
import numpy as np
from IPython.display import Audio
from scipy.io import wavfile
from sklearn.decomposition import PCA

# %%
sample_rate, source_audio = wavfile.read("./data/donuts_hq.wav")
sample_start = sample_rate * 60
sample_end = sample_rate * 70
print("Sample rate:", sample_rate)
# Out:
# Sample rate: 32000

# %%
Audio(source_audio[sample_start:sample_end], rate=sample_rate)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
def compress_with_pca(data, components, block_size=1024):
    samples = len(data)
    leftover = block_size - samples % block_size
    padded = np.lib.pad(data, (0, leftover), "constant", constant_values=0)
    
    reshaped = padded.reshape((len(padded) // block_size, block_size))
    
    pca = PCA(n_components=components)
    pca.fit(reshaped)
    
    transformed = pca.transform(reshaped)
    reconstructed = pca.inverse_transform(transformed).reshape((len(padded)))
    return pca, transformed, reconstructed

# %%
COMPONENT_COUNT = 200
PCA_BLOCK_SIZE = 3200 # 1/10 of the sample rate, which should be 32000 here

pca, transformed, constructed = compress_with_pca(
    source_audio, COMPONENT_COUNT, PCA_BLOCK_SIZE
)
print(f"PCA Transformed audio shape: {transformed.shape}")
Audio(constructed[sample_start:sample_end], rate=sample_rate)
# Out:
# PCA Transformed audio shape: (1741, 200)
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
pca_max = np.amax(transformed)
print(transformed.shape)
print(np.amax(transformed))
print(np.amin(transformed))
normalized = transformed / pca_max
print(normalized.shape)
print(np.amax(normalized))
print(np.amin(normalized))
# Out:
# (1741, 200)
# 972767.7704313479
# -871977.7014758553
# (1741, 200)
# 1.0
# -0.8963883549402547

# %%
train_dataset = tf.data.Dataset.from_tensor_slices(normalized)
train_dataset
# Out:
# <TensorSliceDataset shapes: (200,), types: tf.float64>

# %%
MAXIMUM_SEQUENCE_LENGTH = 16
sequences = train_dataset.batch(
    MAXIMUM_SEQUENCE_LENGTH + 4,
    drop_remainder=True
)
sequences
# Out:
# <BatchDataset shapes: (20, 200), types: tf.float64>

# %%
def split_input_target(sequence):
    input_data = sequence[:-1]
    target_data = sequence[1:]
    return input_data, target_data
    return sequence, sequence

prepared_dataset = sequences.map(split_input_target)
prepared_dataset
# Out:
# <MapDataset shapes: ((19, 200), (19, 200)), types: (tf.float64, tf.float64)>

# %%
BATCH_SIZE = 32
BUFFER_SIZE = 1024
shuffled_dataset = (
    prepared_dataset
    .shuffle(BUFFER_SIZE)
    .batch(BATCH_SIZE, drop_remainder=True)
)

# %%
CHECKPOINT_DIR = "./training-checkpoints/music-generation-with-pca-and-gru"

# %%
def build_model(rnn_units, batch_size):
    model =  tf.keras.Sequential([
        tf.keras.layers.InputLayer(
            batch_size=batch_size,
            input_shape=(None, COMPONENT_COUNT),
            dtype="float32",
        ),
        tf.keras.layers.GRU(
            rnn_units,
            return_sequences=True,
            stateful=True,
            recurrent_initializer="glorot_uniform",
            dtype="float32",
        ),
        tf.keras.layers.Dense(COMPONENT_COUNT, dtype="float32"),
    ])
    return model

# %%
latest_checkpoint = tf.train.latest_checkpoint(CHECKPOINT_DIR)

model = build_model(
    rnn_units=1024,
    batch_size=BATCH_SIZE,
)
model.build()
if latest_checkpoint:
    model.load_weights(latest_checkpoint)
model.summary()
# Out:
# Model: "sequential_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# gru_8 (GRU)                  (32, None, 1024)          3766272
# _________________________________________________________________
# dense_8 (Dense)              (32, None, 200)           205000
# =================================================================
# Total params: 3,971,272
# Trainable params: 3,971,272
# Non-trainable params: 0
# _________________________________________________________________

# %%
for input_batch, target_batch in shuffled_dataset.take(1):
    predictions = model(input_batch)
    print(predictions.shape, "# (batch_size, sequence_length, output)")
    print(predictions[0][0][:10])
    print(target_batch[0][0][:10])
# Out:
# (32, 19, 200) # (batch_size, sequence_length, output)
# tf.Tensor(
# [-0.0552041   0.0135721   0.12493993 -0.03191961  0.04949732  0.07150979
#  -0.00256165 -0.04370787  0.00874729  0.03567329], shape=(10,), dtype=float32)
# tf.Tensor(
# [-0.04246185  0.01961843  0.03615393 -0.04456432  0.04134095  0.02739182
#   0.02832068 -0.1120001   0.03828289 -0.03845181], shape=(10,), dtype=float64)

# %%
def loss(target, predicted):
    return tf.keras.losses.MSE(target, predicted)

# %%
batch_loss = loss(target_batch, predictions)
print("Predictions shape (batch_size, sequence_length, vocabulary_size)")
print(predictions.shape, "\n")
print("scalar_loss:", batch_loss.numpy().mean())
# Out:
# Predictions shape (batch_size, sequence_length, vocabulary_size)
# (32, 19, 200)
#
# scalar_loss: 0.000402696

# %%
model.compile(optimizer="adam", loss=loss)

# %%
checkpoint_prefix = os.path.abspath(
    os.path.join(CHECKPOINT_DIR, "ckpt_{epoch}")
)

checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_prefix,
    save_weights_only=True,
)

# %%
EPOCHS = 100

# %%
history = model.fit(
    shuffled_dataset,
    epochs=EPOCHS,
    callbacks=[checkpoint_callback],
)
# Out:
# Train for 2 steps
# Epoch 1/100
# 2/2 [==============================] - 3s 1s/step - loss: 4.0107e-04
# Epoch 2/100
# 2/2 [==============================] - 3s 1s/step - loss: 3.9652e-04
# Epoch 3/100
# 2/2 [==============================] - 2s 882ms/step - loss: 3.8335e-04
# Epoch 4/100
# 2/2 [==============================] - 1s 604ms/step - loss: 4.0362e-04
# Epoch 5/100
# 2/2 [==============================] - 1s 686ms/step - loss: 4.0317e-04
# Epoch 6/100
# 2/2 [==============================] - 1s 702ms/step - loss: 4.1033e-04
# Epoch 7/100
# 2/2 [==============================] - 1s 547ms/step - loss: 3.8985e-04
# Epoch 8/100
# 2/2 [==============================] - 1s 576ms/step - loss: 3.8584e-04
# Epoch 9/100
# 2/2 [==============================] - 1s 571ms/step - loss: 3.8462e-04
# Epoch 10/100
# 2/2 [==============================] - 1s 559ms/step - loss: 3.6798e-04
# Epoch 11/100
# 2/2 [==============================] - 1s 610ms/step - loss: 3.7845e-04
# Epoch 12/100
# 2/2 [==============================] - 1s 548ms/step - loss: 4.0487e-04
# Epoch 13/100
# 2/2 [==============================] - 1s 571ms/step - loss: 3.8077e-04
# Epoch 14/100
# 2/2 [==============================] - 1s 588ms/step - loss: 3.8613e-04
# Epoch 15/100
# 2/2 [==============================] - 1s 651ms/step - loss: 3.8778e-04
# Epoch 16/100
# 2/2 [==============================] - 1s 686ms/step - loss: 3.6895e-04
# Epoch 17/100
# 2/2 [==============================] - 2s 828ms/step - loss: 3.7585e-04
# Epoch 18/100
# 2/2 [==============================] - 1s 547ms/step - loss: 3.6675e-04
# Epoch 19/100
# 2/2 [==============================] - 1s 559ms/step - loss: 3.6517e-04
# Epoch 20/100
# 2/2 [==============================] - 1s 565ms/step - loss: 3.7691e-04
# Epoch 21/100
# 2/2 [==============================] - 1s 600ms/step - loss: 3.4616e-04
# Epoch 22/100
# 2/2 [==============================] - 1s 565ms/step - loss: 3.6903e-04
# Epoch 23/100
# 2/2 [==============================] - 1s 582ms/step - loss: 3.6515e-04
# Epoch 24/100
# 2/2 [==============================] - 1s 547ms/step - loss: 3.5506e-04
# Epoch 25/100
# 2/2 [==============================] - 1s 559ms/step - loss: 3.5250e-04
# Epoch 26/100
# 2/2 [==============================] - 1s 582ms/step - loss: 3.7977e-04
# Epoch 27/100
# 2/2 [==============================] - 1s 587ms/step - loss: 3.4491e-04
# Epoch 28/100
# 2/2 [==============================] - 1s 571ms/step - loss: 3.7486e-04
# Epoch 29/100
# 2/2 [==============================] - 2s 781ms/step - loss: 3.7501e-04
# Epoch 30/100
# 2/2 [==============================] - 1s 636ms/step - loss: 3.5130e-04
# Epoch 31/100
# 2/2 [==============================] - 1s 588ms/step - loss: 3.6667e-04
# Epoch 32/100
# 2/2 [==============================] - 1s 744ms/step - loss: 3.7669e-04
# Epoch 33/100
# 2/2 [==============================] - 1s 593ms/step - loss: 3.6833e-04
# Epoch 34/100
# 2/2 [==============================] - 1s 565ms/step - loss: 3.3908e-04
# Epoch 35/100
# 2/2 [==============================] - 1s 605ms/step - loss: 3.6390e-04
# Epoch 36/100
# 2/2 [==============================] - 1s 599ms/step - loss: 3.3059e-04
# Epoch 37/100
# 2/2 [==============================] - 1s 548ms/step - loss: 3.6835e-04
# Epoch 38/100
# 2/2 [==============================] - 1s 558ms/step - loss: 3.3314e-04
# Epoch 39/100
# 2/2 [==============================] - 1s 547ms/step - loss: 3.5565e-04
# Epoch 40/100
# 2/2 [==============================] - 1s 571ms/step - loss: 3.4464e-04
# Epoch 41/100
# 2/2 [==============================] - 1s 587ms/step - loss: 3.4349e-04
# Epoch 42/100
# 2/2 [==============================] - 1s 594ms/step - loss: 3.3469e-04
# Epoch 43/100
# 2/2 [==============================] - 1s 594ms/step - loss: 3.3435e-04
# Epoch 44/100
# 2/2 [==============================] - 1s 570ms/step - loss: 3.4603e-04
# Epoch 45/100
# 2/2 [==============================] - 1s 559ms/step - loss: 3.5378e-04
# Epoch 46/100
# 2/2 [==============================] - 1s 571ms/step - loss: 3.4648e-04
# Epoch 47/100
# 2/2 [==============================] - 1s 583ms/step - loss: 3.3888e-04
# Epoch 48/100
# 2/2 [==============================] - 1s 566ms/step - loss: 3.3427e-04
# Epoch 49/100
# 2/2 [==============================] - 1s 517ms/step - loss: 3.5844e-04
# Epoch 50/100
# 2/2 [==============================] - 1s 605ms/step - loss: 3.4301e-04
# Epoch 51/100
# 2/2 [==============================] - 1s 622ms/step - loss: 3.3553e-04
# Epoch 52/100
# 2/2 [==============================] - 1s 611ms/step - loss: 3.3991e-04
# Epoch 53/100
# 2/2 [==============================] - 1s 558ms/step - loss: 3.3519e-04
# Epoch 54/100
# 2/2 [==============================] - 1s 587ms/step - loss: 3.4078e-04
# Epoch 55/100
# 2/2 [==============================] - 1s 617ms/step - loss: 3.3666e-04
# Epoch 56/100
# 2/2 [==============================] - 1s 570ms/step - loss: 3.2011e-04
# Epoch 57/100
# 2/2 [==============================] - 1s 554ms/step - loss: 3.2979e-04
# Epoch 58/100
# 2/2 [==============================] - 1s 519ms/step - loss: 3.4119e-04
# Epoch 59/100
# 2/2 [==============================] - 1s 582ms/step - loss: 3.2681e-04
# Epoch 60/100
# 2/2 [==============================] - 1s 634ms/step - loss: 3.3317e-04
# Epoch 61/100
# 2/2 [==============================] - 1s 553ms/step - loss: 3.3167e-04
# Epoch 62/100
# 2/2 [==============================] - 1s 571ms/step - loss: 3.4703e-04
# Epoch 63/100
# 2/2 [==============================] - 1s 530ms/step - loss: 3.5331e-04
# Epoch 64/100
# 2/2 [==============================] - 1s 560ms/step - loss: 3.2467e-04
# Epoch 65/100
# 2/2 [==============================] - 1s 587ms/step - loss: 3.1960e-04
# Epoch 66/100
# 2/2 [==============================] - 1s 565ms/step - loss: 3.2297e-04
# Epoch 67/100
# 2/2 [==============================] - 1s 582ms/step - loss: 3.3193e-04
# Epoch 68/100
# 2/2 [==============================] - 1s 547ms/step - loss: 3.2300e-04
# Epoch 69/100
# 2/2 [==============================] - 1s 589ms/step - loss: 3.2772e-04
# Epoch 70/100
# 2/2 [==============================] - 1s 599ms/step - loss: 3.1941e-04
# Epoch 71/100
# 2/2 [==============================] - 1s 657ms/step - loss: 3.2016e-04
# Epoch 72/100
# 2/2 [==============================] - 1s 553ms/step - loss: 3.3500e-04
# Epoch 73/100
# 2/2 [==============================] - 1s 576ms/step - loss: 3.3867e-04
# Epoch 74/100
# 2/2 [==============================] - 1s 582ms/step - loss: 3.3064e-04
# Epoch 75/100
# 2/2 [==============================] - 1s 576ms/step - loss: 3.0312e-04
# Epoch 76/100
# 2/2 [==============================] - 1s 553ms/step - loss: 3.0810e-04
# Epoch 77/100
# 2/2 [==============================] - 1s 554ms/step - loss: 3.1891e-04
# Epoch 78/100
# 2/2 [==============================] - 2s 801ms/step - loss: 3.0726e-04
# Epoch 79/100
# 2/2 [==============================] - 1s 536ms/step - loss: 3.2268e-04
# Epoch 80/100
# 2/2 [==============================] - 1s 576ms/step - loss: 3.3346e-04
# Epoch 81/100
# 2/2 [==============================] - 1s 599ms/step - loss: 3.1683e-04
# Epoch 82/100
# 2/2 [==============================] - 1s 605ms/step - loss: 3.0758e-04
# Epoch 83/100
# 2/2 [==============================] - 1s 565ms/step - loss: 3.2012e-04
# Epoch 84/100
# 2/2 [==============================] - 1s 564ms/step - loss: 3.1356e-04
# Epoch 85/100
# 2/2 [==============================] - 1s 749ms/step - loss: 3.2189e-04
# Epoch 86/100
# 2/2 [==============================] - 1s 628ms/step - loss: 3.0053e-04
# Epoch 87/100
# 2/2 [==============================] - 1s 599ms/step - loss: 3.1471e-04
# Epoch 88/100
# 2/2 [==============================] - 1s 588ms/step - loss: 3.0856e-04
# Epoch 89/100
# 2/2 [==============================] - 1s 547ms/step - loss: 3.1599e-04
# Epoch 90/100
# 2/2 [==============================] - 1s 565ms/step - loss: 3.2557e-04
# Epoch 91/100
# 2/2 [==============================] - 1s 593ms/step - loss: 3.3288e-04
# Epoch 92/100
# 2/2 [==============================] - 1s 587ms/step - loss: 3.1694e-04
# Epoch 93/100
# 2/2 [==============================] - 1s 634ms/step - loss: 3.0851e-04
# Epoch 94/100
# 2/2 [==============================] - 1s 576ms/step - loss: 3.2525e-04
# Epoch 95/100
# 2/2 [==============================] - 1s 570ms/step - loss: 3.1522e-04
# Epoch 96/100
# 2/2 [==============================] - 1s 588ms/step - loss: 3.0777e-04
# Epoch 97/100
# 2/2 [==============================] - 1s 541ms/step - loss: 3.0900e-04
# Epoch 98/100
# 2/2 [==============================] - 1s 559ms/step - loss: 3.1015e-04
# Epoch 99/100
# 2/2 [==============================] - 1s 577ms/step - loss: 3.0761e-04
# Epoch 100/100
# 2/2 [==============================] - 1s 639ms/step - loss: 3.1535e-04

# %%
model = build_model(
    rnn_units=1024,
    batch_size=1,
)
model.load_weights(tf.train.latest_checkpoint(CHECKPOINT_DIR))
model.build(tf.TensorShape([1, None]))
model.summary()
# Out:
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# gru_9 (GRU)                  (1, None, 1024)           3766272
# _________________________________________________________________
# dense_9 (Dense)              (1, None, 200)            205000
# =================================================================
# Total params: 3,971,272
# Trainable params: 3,971,272
# Non-trainable params: 0
# _________________________________________________________________

# %%
def generate_output(model, input_eval, samples_to_generate=4000):
    generated_output = []
    
    model.reset_states()
    for i in range(samples_to_generate):
        predictions = model(input_eval)
        prediction = predictions[0, -1].numpy()
        input_eval = tf.expand_dims([prediction], 0)
        generated_output.append(prediction)
        if i % 50 == 0:
            print(f"Generated {i} / {samples_to_generate}")
    print("Done!")
    
    return generated_output

# %%
initial = list(shuffled_dataset.take(1))[0][0][0]
initial = tf.expand_dims(initial, 0)
Audio(pca.inverse_transform(initial * pca_max).flatten(), rate=sample_rate)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
output = generate_output(model, initial, samples_to_generate=200)
output = np.array(output) * pca_max
# model.reset_states()
# output = model(initial) * pca_max
# Out:
# Generated 0 / 200
# Generated 50 / 200
# Generated 100 / 200
# Generated 150 / 200
# Done!

# %%
output_reconstructed = pca.inverse_transform(output).flatten()
output_reconstructed *= pca_max
Audio(output_reconstructed, rate=sample_rate)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
